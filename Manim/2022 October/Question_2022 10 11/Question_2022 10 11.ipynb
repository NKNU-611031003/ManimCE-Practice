# %% [markdown]
# <a href="https://colab.research.google.com/github/NKNU-611031003/ManimCE-Practice/blob/main/Manim/2022%20October/Question_2022%2010%2011/Question_2022%2010%2011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !sudo apt install texlive-full
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 261 kB in 1s (293 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 22 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# texlive-latex-recommended is already the newest version (2017.20180305-1).
# texlive is already the newest version (2017.20180305-1).
# texlive-fonts-extra is already the newest version (2017.20180305-2).
# texlive-latex-extra is already the newest version (2017.20180305-2).
# texlive-science is already the newest version (2017.20180305-2).
# tipa is already the newest version (2:1.3-20).
# libcairo2-dev is already the newest version (1.15.10-2ubuntu0.1).
# libpango1.0-dev is already the newest version (1.40.14-1ubuntu0.1).
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# texlive-full is already the newest version (2017.20180305-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: manim in /usr/local/lib/python3.7/dist-packages (0.16.0.post0)
# Requirement already satisfied: click-default-group<2.0.0,>=1.2.2 in /usr/local/lib/python3.7/dist-packages (from manim) (1.2.2)
# Requirement already satisfied: rich!=12.0.0,>=6.0 in /usr/local/lib/python3.7/dist-packages (from manim) (12.6.0)
# Requirement already satisfied: click>=7.2 in /usr/local/lib/python3.7/dist-packages (from manim) (8.1.3)
# Requirement already satisfied: importlib-metadata<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from manim) (4.13.0)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from manim) (1.7.3)
# Requirement already satisfied: backports.cached-property<2.0.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from manim) (1.0.2)
# Requirement already satisfied: watchdog<3.0.0,>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from manim) (2.1.9)
# Requirement already satisfied: manimpango<0.5.0,>=0.4.0.post0 in /usr/local/lib/python3.7/dist-packages (from manim) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.26.0 in /usr/local/lib/python3.7/dist-packages (from manim) (2.28.1)
# Requirement already satisfied: moderngl-window<3.0.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from manim) (2.4.2)
# Requirement already satisfied: moderngl<6.0.0,>=5.6.3 in /usr/local/lib/python3.7/dist-packages (from manim) (5.6.4)
# Requirement already satisfied: numpy<2.0,>=1.19 in /usr/local/lib/python3.7/dist-packages (from manim) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.62.3 in /usr/local/lib/python3.7/dist-packages (from manim) (4.64.1)
# Requirement already satisfied: skia-pathops<0.8.0,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from manim) (0.7.2)
# Requirement already satisfied: colour<0.2.0,>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from manim) (0.1.5)
# Requirement already satisfied: cloup<0.14.0,>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from manim) (0.13.1)
# Requirement already satisfied: Pillow<10.0,>=9.1 in /usr/local/lib/python3.7/dist-packages (from manim) (9.2.0)
# Requirement already satisfied: networkx<3.0,>=2.5 in /usr/local/lib/python3.7/dist-packages (from manim) (2.6.3)
# Requirement already satisfied: isosurfaces==0.1.0 in /usr/local/lib/python3.7/dist-packages (from manim) (0.1.0)
# Requirement already satisfied: pycairo<2.0,>=1.19 in /usr/local/lib/python3.7/dist-packages (from manim) (1.21.0)
# Requirement already satisfied: screeninfo<0.9,>=0.8 in /usr/local/lib/python3.7/dist-packages (from manim) (0.8.1)
# Requirement already satisfied: srt<4.0.0,>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from manim) (3.5.2)
# Requirement already satisfied: decorator<6.0.0,>=5.0.7 in /usr/local/lib/python3.7/dist-packages (from manim) (5.1.1)
# Requirement already satisfied: mapbox-earcut<0.13.0,>=0.12.10 in /usr/local/lib/python3.7/dist-packages (from manim) (0.12.11)
# Requirement already satisfied: pydub<0.26.0,>=0.25.1 in /usr/local/lib/python3.7/dist-packages (from manim) (0.25.1)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from manim) (2.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cloup<0.14.0,>=0.13.0->manim) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0,>=4.10.0->manim) (3.8.1)
# Requirement already satisfied: glcontext<3,>=2 in /usr/local/lib/python3.7/dist-packages (from moderngl<6.0.0,>=5.6.3->manim) (2.3.6)
# Requirement already satisfied: pyglet>=2.0dev23 in /usr/local/lib/python3.7/dist-packages (from moderngl-window<3.0.0,>=2.3.0->manim) (2.0a4)
# Requirement already satisfied: pyrr<1,>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from moderngl-window<3.0.0,>=2.3.0->manim) (0.10.3)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.7/dist-packages (from pyrr<1,>=0.10.3->moderngl-window<3.0.0,>=2.3.0->manim) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->manim) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->manim) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->manim) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->manim) (1.24.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich!=12.0.0,>=6.0->manim) (0.9.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from multipledispatch->pyrr<1,>=0.10.3->moderngl-window<3.0.0,>=2.3.0->manim) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (7.34.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython) (2.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from IPython) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from IPython) (0.1.6)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython) (5.1.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from IPython) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from IPython) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (1.15.0)

# %%
from manim import *
def ManimCELogo(self):
    # logo
    banner = ManimBanner(dark_theme=False)
    circle_banner = Circle(color="#ece6e2", fill_opacity=1).surround(banner).scale(2)
    # logo Text
    logo_Text = Text("Manim Community", font_size=48).shift(RIGHT)
    logo_MadeBy = Text("Made by", font_size=24).next_to(logo_Text, UP).shift(LEFT*2.5)
    logo_Web = Text("https://docs.manim.community/en/stable/index.html", font_size=16).next_to(logo_Text, DOWN)
    # Group
    banner_Group = VGroup(circle_banner, banner)
    logo_Text_Group = Group(logo_MadeBy, logo_Web)

    self.play(FadeIn(circle_banner), banner.create())
    self.play(banner.animate.scale(0.2), circle_banner.animate.scale(0.1))
    self.play(banner_Group.animate.next_to(logo_Text_Group, LEFT))
    self.play(FadeIn(logo_Text_Group), Write(logo_Text), run_time=2.5)
    self.wait(3)
    self.play(FadeOut(banner_Group), FadeOut(logo_Text_Group), FadeOut(logo_Text))
    self.wait()

# %% [markdown]
# ### 正片

# %%
# %%manim -qm -v WARNING MathQuestion_221011
# import argparse
#
# parser = argparse.ArgumentParser()
# parser.add_argument('-f')
# parser.add_argument("--font_size", type=int, default=50)
# parser.add_argument("--font_size_small", type=int, default=40)
# parser.add_argument("--black_opacity", type=float, default=0.5, help="function that has used")
# parser.add_argument("--FadeIn_runtime", type=float, default=1.0)
# parser.add_argument("--framebox_1_time", type=float, default=1.5, help="first framebox animate run time")
# parser.add_argument("--wait_time", type=float, default=1.5)
#
# class MathQuestion_221011(Scene):
#   def construct(self):
#     args = parser.parse_args()
#
#     ManimCELogo(self)
#     main_Function(self)
#     Answer(self)
#
# def main_Function(self):
#     args = parser.parse_args()
#
#     question_Tex = MathTex("f(x,y) =", "x^2 + 2xy +", "3", "y^2", "+ 4x + 5y + 6", font_size=args.font_size).shift(UP)
#     question_Text = Tex(r'問：當$f(x,y)$有最小值時，求 $x$, $y$ ？ ', tex_template=TexTemplateLibrary.ctex, font_size=args.font_size)
#     question = VGroup(question_Tex, question_Text)
#     self.play(Write(question))
#     self.wait(2)
#     # 解答開始
#     self.play(FadeOut(question_Text))
#     self.wait()
#     self.play(question_Tex.animate.move_to(UP*3))
#     self.wait()
#
#     eq_Group_1 = VGroup(*[question_Tex[i] for i in range(1, 4)])
#     framebox_1 = SurroundingRectangle(eq_Group_1, buff=0.1)
#     self.play(ShowPassingFlash(framebox_1), run_time=args.framebox_1_time, time_width=2)
#
#     # 公式
#     eq_0_1 = MathTex("f(x,y) =", "x^2 + 2xy +", "3", "y^2", "+ 4x + 5y + 6", font_size=args.font_size).move_to(question_Tex)
#     for i in range(1, 4):
#       eq_0_1[i].set_color(RED)
#     eq_0_2 = MathTex("f(x,y) =", "x^2 + 2xy +", "y^2", "+ 2y^2", "+ 4x + 5y + 6", font_size=args.font_size)
#     for i in range(1, 3):
#       eq_0_2[i].set_color(RED)
#     eq_0_2[3].set_color(BLUE)
#
#     eq_1_1 = MathTex("f(x,y) =", "x^2 + 2xy + y^2", "+ 2y^2", "+ 4x + 5y + 6", font_size=args.font_size).move_to(eq_0_2)
#     eq_1_1[1].set_color(RED)
#     eq_1_1[2].set_color(BLUE)
#     eq_1_2 = MathTex("f(x,y) =", "(x + y)^2", "+ 2y^2", "+ 4x + 5y + 6", font_size=args.font_size).move_to(ORIGIN)
#     eq_1_2[1].set_color(RED)
#     eq_1_2[2].set_color(BLUE)
#
#     eq_2_1 = MathTex("f(x,y) =", "(x + y)^2", "+ 2y^2", "+ 4x + 5y+ 6", font_size=args.font_size).move_to(ORIGIN)
#     eq_2_1[2].set_color(BLUE)
#     eq_2_2 = MathTex("f(x,y) =", "(x + y)^2", "+ 4x + 5y + 6", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#     eq_2_2[3].set_color(BLUE)
#     eq_2_3 = eq_2_2.copy().move_to(eq_2_2)
#     eq_2_3[3].set_color(WHITE)
#
#     eq_3_1 = MathTex("f(x,y) =", "(x + y)^2 + 4x ", "+", "5y", "+", "6", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#     eq_3_2 = MathTex("f(x,y) =", "(x + y)^2 + 4x ", "+ 4y", "+ y", "+ 4", "+ 2", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#     for i in np.array([1, 2, 4]):
#       eq_3_2[i].set_color(RED)
#     for i in np.array([3, 5]):
#       eq_3_2[i].set_color(BLUE)
#     eq_3_3 = MathTex("f(x,y) =", "(x + y)^2 + 4x ", "+ 4y", "+ 4", "+ 2", "+ y", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#
#     eq_4_1 = MathTex("f(x,y) =", "(x + y)^2 + 4x + 4y + 4", "+ y + 2", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#     eq_4_1[1].set_color(RED)
#     eq_4_1[2].set_color(BLUE)
#     eq_4_2 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ y + 2", "+ 2y^2", font_size=args.font_size).move_to(ORIGIN)
#     eq_4_2[1].set_color(RED)
#     eq_4_2[2].set_color(BLUE)
#     eq_4_3 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2y^2", "+ y + 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_4_4 = eq_4_3.copy().move_to(eq_4_2)
#     for i in range(1, 4):
#       eq_4_4[i].set_color(WHITE)
#
#     eq_5_1 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2y^2 + y", "+ 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_5_2 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,(y^2 + \cfrac{y}{2})", "+ 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_5_2[2].set_color(RED)
#
#     eq_6_1 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,", "(y^2 + \cfrac{y}{2}", ")", "+", "2", font_size=args.font_size).move_to(ORIGIN)
#     for i in range(2, 5):
#       eq_6_1[i].set_color(RED)
#     eq_6_2 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,", "(y^2 + \cfrac{y}{2}", "+ \cfrac{1}{16})", "- \cfrac{1}{8}", "+ 2", font_size=args.font_size).move_to(ORIGIN)
#     for i in range(2, 5):
#       eq_6_2[i].set_color(RED)
#     eq_6_2[5].set_color(BLUE)
#
#     eq_7_1 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,", "(y^2 + \cfrac{y}{2} + \cfrac{1}{16})", "- \cfrac{1}{8}", "+ 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_7_1[2].set_color(RED)
#     eq_7_1[3].set_color(RED)
#     eq_7_1[4].set_color(BLUE)
#     eq_7_2 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,", "(y + \cfrac{1}{4})^2", "- \cfrac{1}{8}", "+ 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_7_2[2].set_color(RED)
#     eq_7_2[3].set_color(RED)
#     eq_7_2[4].set_color(BLUE)
#
#     eq_8_1 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,(y + \cfrac{1}{4})^2", "- \cfrac{1}{8} + 2", font_size=args.font_size).move_to(ORIGIN)
#     eq_8_2 = MathTex("f(x,y) =", "(x + y + 2)^2 ", "+ 2\,(y + \cfrac{1}{4})^2", "+ \cfrac{15}{8}", font_size=args.font_size).move_to(ORIGIN)
#
#     self.play(FadeIn(eq_0_1))
#     self.play(question_Tex.animate.set_opacity(args.black_opacity), eq_0_1.animate.move_to(ORIGIN))
#     self.wait()
#     self.play(ReplacementTransform(eq_0_1, eq_0_2))
#     self.wait(args.wait_time)
#
#     self.play(ReplacementTransform(eq_0_2, eq_1_1), run_time=0)
#     self.play(ReplacementTransform(eq_1_1, eq_1_2))
#     self.wait(args.wait_time)
#
#     self.play(eq_1_2[1].animate.set_color(WHITE))
#     self.play(ReplacementTransform(eq_1_2, eq_2_1), run_time=0)
#     self.play(eq_2_1[2].animate.move_to(eq_2_2[3]), eq_2_1[3].animate.move_to(eq_2_2[2]))
#     self.play(ReplacementTransform(eq_2_1, eq_2_2), run_time=0)
#     self.play(eq_2_2[3].animate.set_color(WHITE))
#     self.wait(args.wait_time)
#     self.play(eq_2_3.animate.move_to(UP*2).set_opacity(args.black_opacity))
#
#     self.play(*[eq_3_1[i].animate.set_color(RED) for i in range(1, 6)])
#     self.play(ReplacementTransform(eq_2_2, eq_3_1), run_time=0)
#     self.play(ReplacementTransform(eq_3_1, eq_3_2))
#     self.play(eq_3_2[3].animate.move_to(eq_3_3[4]), eq_3_2[4].animate.move_to(eq_3_3[3]))
#     self.wait(args.wait_time)
#
#     self.play(ReplacementTransform(eq_3_2, eq_4_1), run_time=0)
#     self.play(ReplacementTransform(eq_4_1, eq_4_2))
#     self.play(eq_4_2[1].animate.set_color(WHITE))
#     self.play(eq_4_2[2].animate.move_to(eq_4_3[3]), eq_4_2[3].animate.move_to(eq_4_3[2]))
#     self.play(eq_4_2[2].animate.set_color(WHITE))
#     self.wait(args.wait_time)
#     self.play(eq_4_4.animate.move_to(UP).set_opacity(args.black_opacity))
#
#     self.play(ReplacementTransform(eq_4_2, eq_5_1), run_time=0)
#     self.play(eq_5_1[2].animate.set_color(RED))
#     self.play(ReplacementTransform(eq_5_1, eq_5_2))
#     self.wait(args.wait_time)
#
#     self.play(ReplacementTransform(eq_5_2, eq_6_1), run_time=0)
#     self.play(ReplacementTransform(eq_6_1, eq_6_2))
#     self.wait(args.wait_time)
#
#     self.play(ReplacementTransform(eq_6_2, eq_7_1), run_time=0)
#     self.play(ReplacementTransform(eq_7_1, eq_7_2))
#     self.play(eq_7_2[2].animate.set_color(WHITE), eq_7_2[3].animate.set_color(WHITE), eq_7_2[4].animate.set_color(WHITE))
#     self.wait(args.wait_time)
#
#     self.play(ReplacementTransform(eq_7_2, eq_8_1), run_time=0)
#     self.play(ReplacementTransform(eq_8_1, eq_8_2))
#     self.wait(args.wait_time)
#
# def Answer(self):
#     args = parser.parse_args()
#
#     answer_Text_1 = Text("平方項為 0 時可產生最小值", font_size=args.font_size_small).shift(DOWN)
#     answer_Text_2 = Tex("即：$x=-\cfrac{7}{4}$ , $y=-\cfrac{1}{4}$", tex_template=TexTemplateLibrary.ctex, font_size=args.font_size).shift(DOWN*2)
#     self.play(Write(answer_Text_1), run_time=1.5)
#     self.play(Write(answer_Text_2), run_time=1.5)
#     self.wait(args.wait_time)
# Out:
# Animation 19: ReplacementTransform(MathTex('f(x,y) = x^2 + 2xy + y^2 + 2y^2 + 4x + 5y + 6')):   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/manim/scene/scene.py:1427: RuntimeWarning: invalid value encountered in long_scalars
#   alpha = t / animation.run_time
# Animation 25: ReplacementTransform(MathTex('f(x,y) = (x + y)^2 + 2y^2 + 4x + 5y+ 6')):   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/manim/scene/scene.py:1427: RuntimeWarning: invalid value encountered in long_scalars
#   alpha = t / animation.run_time
# Animation 34: ReplacementTransform(MathTex('f(x,y) = (x + y)^2 + 4x  + 4y + y + 4 + 2 + 2y^2')):   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/manim/scene/scene.py:1427: RuntimeWarning: invalid value encountered in long_scalars
#   alpha = t / animation.run_time
# Animation 45: ReplacementTransform(MathTex('f(x,y) = (x + y + 2)^2  + 2\\,(y^2 + \\cfrac{y}{2}) + 2')):   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/manim/scene/scene.py:1427: RuntimeWarning: invalid value encountered in long_scalars
#   alpha = t / animation.run_time
# Animation 52: ReplacementTransform(MathTex('f(x,y) = (x + y + 2)^2  + 2\\, (y + \\cfrac{1}{4})^2 - \\cfrac{1}{8} + 2')):   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/manim/scene/scene.py:1427: RuntimeWarning: invalid value encountered in long_scalars
#   alpha = t / animation.run_time
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
